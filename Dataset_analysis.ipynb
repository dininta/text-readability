# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn

# %%
data = pd.read_csv('./train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2834 entries, 0 to 2833
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2834 non-null   object
#  1   url_legal       830 non-null    object
#  2   license         830 non-null    object
#  3   excerpt         2834 non-null   object
#  4   target          2834 non-null   float64
#  5   standard_error  2834 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 133.0+ KB

# %%
data=data.drop(columns=['id', 'url_legal','license'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2834 entries, 0 to 2833
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   excerpt         2834 non-null   object
#  1   target          2834 non-null   float64
#  2   standard_error  2834 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 66.5+ KB

# %%
print(data.describe())
print(data.head())
# Out:
#             target  standard_error
# count  2834.000000     2834.000000
# mean     -0.959319        0.491435
# std       1.033579        0.034818
# min      -3.676268        0.000000
# 25%      -1.690320        0.468543
# 50%      -0.912190        0.484721
# 75%      -0.202540        0.506268
# max       1.711390        0.649671
#                                              excerpt    target  standard_error
# 0  When the young people returned to the ballroom... -0.340259        0.464009
# 1  All through dinner time, Mrs. Fayre was somewh... -0.315372        0.480805
# 2  As Roger had predicted, the snow departed as q... -0.580118        0.476676
# 3  And outside before the palace a great garden w... -1.054013        0.450007
# 4  Once upon a time there were Three Bears who li...  0.247197        0.510845

# %%
print("MOST DIFFICULT TEXT: ")
print()
print(data.iat[data[data['target']==data['target'].min()].index[0],0])
print()
print("EASIEST TEXT: ")
print()
print(data.iat[data[data['target']==data['target'].max()].index[0],0])
# Out:
# MOST DIFFICULT TEXT:
#
# ...

# %%
data.hist(bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'target'}>,
#         <AxesSubplot:title={'center':'standard_error'}>]], dtype=object)

# %%
lengths=[]
for x in data['excerpt']:
    lengths.append(len(x))
data['lenghts']=lengths

# %%
data.describe()
# Out:
#             target  standard_error      lenghts
# count  2834.000000     2834.000000  2834.000000
# mean     -0.959319        0.491435   973.236415
# std       1.033579        0.034818   117.240491
# min      -3.676268        0.000000   674.000000
# 25%      -1.690320        0.468543   887.000000
# 50%      -0.912190        0.484721   972.000000
# 75%      -0.202540        0.506268  1059.000000
# max       1.711390        0.649671  1343.000000

# %%
data.hist(bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'target'}>,
#         <AxesSubplot:title={'center':'standard_error'}>],
#        [<AxesSubplot:title={'center':'lenghts'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
seaborn.pairplot(data)

# %%
print(data.corr())
# Out:
#                   target  standard_error   lenghts
# target          1.000000       -0.085981 -0.359046
# standard_error -0.085981        1.000000  0.050987
# lenghts        -0.359046        0.050987  1.000000
